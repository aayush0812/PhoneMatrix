# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
data = pd.read_csv('/kaggle/input/mobile-price/train.csv')
data_test = pd.read_csv('/kaggle/input/mobile-price/test.csv')
df = pd.DataFrame(data)
df_test = pd.DataFrame(data_test)
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
df_test = df_test.drop(columns = 'id')
df_test
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0      0.1        193        3  16        226      1412  3476    12     7
# 1      0.8        191        5  12        746       857  3895     6     0
# 2      0.9        186        3   4       1270      1366  2396    17    10
# 3      0.5         96        8  20        295      1752  3893    10     0
# 4      0.5        108        6  18        749       810  1773    15     8
# ..     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 995    0.5        170        7  17        644       913  2121    14     8
# 996    0.9        186        4   2       1152      1632  1933     8     1
# 997    0.5         80        1  12        477       825  1223     5     0
# 998    0.4        171        2  12         38       832  2509    15    11
# 999    0.1        140        6  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# 0            2        0             1     0
# 1            7        1             0     0
# 2           10        0             1     1
# 3            7        1             1     0
# 4            7        1             0     1
# ..         ...      ...           ...   ...
# 995         15        1             1     0
# 996         19        0             1     1
# 997         14        1             0     0
# 998          6        0             1     0
# 999          3        1             0     1
#
# [1000 rows x 20 columns]

# %%
list(df.columns)
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
df.describe().T.style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_af9b9_row0_col0, #T_af9b9_row1_col0, #T_af9b9_row1_col1, #T_af9b9_row1_col2, #T_af9b9_row1_col3, #T_af9b9_row1_col4, #T_af9b9_row1_col5, #T_af9b9_row1_col6, #T_af9b9_row1_col7, #T_af9b9_row2_col0, #T_af9b9_row2_col1, #T_af9b9_row2_col2, #T_af9b9_row2_col3, #T_af9b9_row2_col4, #T_af9b9_row2_col5, #T_af9b9_row2_col6, #T_af9b9_row2_col7, #T_af9b9_row3_col0, #T_af9b9_row3_col1, #T_af9b9_row3_col2, #T_af9b9_row3_col3, #T_af9b9_row3_col4, #T_af9b9_row3_col5, #T_af9b9_row3_col6, #T_af9b9_row3_col7, #T_af9b9_row4_col0, #T_af9b9_row4_col1, #T_af9b9_row4_col2, #T_af9b9_row4_col3, #T_af9b9_row4_col4, #T_af9b9_row4_col5, #T_af9b9_row4_col6, #T_af9b9_row5_col0, #T_af9b9_row5_col1, #T_af9b9_row5_col2, #T_af9b9_row5_col3, #T_af9b9_row5_col4, #T_af9b9_row5_col5, #T_af9b9_row5_col6, #T_af9b9_row5_col7, #T_af9b9_row6_col0, #T_af9b9_row7_col0, #T_af9b9_row7_col1, #T_af9b9_row7_col2, #T_af9b9_row7_col3, #T_af9b9_row7_col4, #T_af9b9_row7_col5, #T_af9b9_row7_col6, #T_af9b9_row7_col7, #T_af9b9_row8_col0, #T_af9b9_row9_col0, #T_af9b9_row9_col1, #T_af9b9_row9_col2, #T_af9b9_row9_col3, #T_af9b9_row9_col4, #T_af9b9_row9_col5, #T_af9b9_row9_col6, #T_af9b9_row9_col7, #T_af9b9_row10_col0, #T_af9b9_row10_col3, #T_af9b9_row11_col0, #T_af9b9_row11_col3, #T_af9b9_row12_col0, #T_af9b9_row13_col0, #T_af9b9_row14_col0, #T_af9b9_row14_col2, #T_af9b9_row15_col0, #T_af9b9_row15_col1, #T_af9b9_row15_col2, #T_af9b9_row15_col3, #T_af9b9_row15_col4, #T_af9b9_row15_col5, #T_af9b9_row15_col6, #T_af9b9_row16_col0, #T_af9b9_row17_col0, #T_af9b9_row17_col1, #T_af9b9_row17_col2, #T_af9b9_row17_col3, #T_af9b9_row17_col4, #T_af9b9_row17_col5, #T_af9b9_row17_col6, #T_af9b9_row17_col7, #T_af9b9_row18_col0, #T_af9b9_row18_col1, #T_af9b9_row18_col2, #T_af9b9_row18_col3, #T_af9b9_row18_col4, #T_af9b9_row18_col5, #T_af9b9_row18_col6, #T_af9b9_row18_col7, #T_af9b9_row19_col0, #T_af9b9_row19_col1, #T_af9b9_row19_col2, #T_af9b9_row19_col3, #T_af9b9_row19_col4, #T_af9b9_row19_col5, #T_af9b9_row19_col6, #T_af9b9_row19_col7, #T_af9b9_row20_col0, #T_af9b9_row20_col1, #T_af9b9_row20_col2, #T_af9b9_row20_col3, #T_af9b9_row20_col4, #T_af9b9_row20_col5, #T_af9b9_row20_col6, #T_af9b9_row20_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_af9b9_row0_col1 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_af9b9_row0_col2 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_af9b9_row0_col3, #T_af9b9_row12_col3, #T_af9b9_row13_col1, #T_af9b9_row13_col2, #T_af9b9_row13_col4, #T_af9b9_row13_col5, #T_af9b9_row13_col6, #T_af9b9_row13_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_af9b9_row0_col4 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_af9b9_row0_col5 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_af9b9_row0_col6 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_af9b9_row0_col7, #T_af9b9_row12_col7 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_af9b9_row4_col7, #T_af9b9_row6_col3, #T_af9b9_row10_col1, #T_af9b9_row10_col2, #T_af9b9_row10_col4, #T_af9b9_row10_col5, #T_af9b9_row10_col6, #T_af9b9_row10_col7, #T_af9b9_row14_col1, #T_af9b9_row14_col4, #T_af9b9_row14_col5, #T_af9b9_row14_col6, #T_af9b9_row14_col7, #T_af9b9_row15_col7, #T_af9b9_row16_col1, #T_af9b9_row16_col2, #T_af9b9_row16_col3, #T_af9b9_row16_col4, #T_af9b9_row16_col5, #T_af9b9_row16_col6, #T_af9b9_row16_col7 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_af9b9_row6_col1, #T_af9b9_row6_col4, #T_af9b9_row6_col5, #T_af9b9_row6_col6 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_af9b9_row6_col2, #T_af9b9_row6_col7 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_af9b9_row8_col1, #T_af9b9_row8_col5 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_af9b9_row8_col2 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_af9b9_row8_col3 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_af9b9_row8_col4 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_af9b9_row8_col6 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_af9b9_row8_col7 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_af9b9_row11_col1 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_af9b9_row11_col2 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_af9b9_row11_col4 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_af9b9_row11_col5 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_af9b9_row11_col6 {
#   background-color: #33628d;
#   color: #f1f1f1;
# }
# #T_af9b9_row11_col7 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_af9b9_row12_col1 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_af9b9_row12_col2 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_af9b9_row12_col4 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_af9b9_row12_col5 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_af9b9_row12_col6 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_af9b9_row13_col3 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_af9b9_row14_col3 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_af9b9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af9b9_level0_row0" class="row_heading level0 row0" >battery_power</th>
#       <td id="T_af9b9_row0_col0" class="data row0 col0" >2000.000000</td>
#       <td id="T_af9b9_row0_col1" class="data row0 col1" >1238.518500</td>
#       <td id="T_af9b9_row0_col2" class="data row0 col2" >439.418206</td>
#       <td id="T_af9b9_row0_col3" class="data row0 col3" >501.000000</td>
#       <td id="T_af9b9_row0_col4" class="data row0 col4" >851.750000</td>
#       <td id="T_af9b9_row0_col5" class="data row0 col5" >1226.000000</td>
#       <td id="T_af9b9_row0_col6" class="data row0 col6" >1615.250000</td>
#       <td id="T_af9b9_row0_col7" class="data row0 col7" >1998.000000</td>
#     </tr>
#     <tr>
#       <th id="T_af9b9_level0_row1" class="row_heading level0 row1" >blue</th>
#       <td id="T_af9b9_row1_col0" class="data row1 col0" >2000.000000</td>
#       <td id="T_af9b9_row1_col1" class="data row1 col1" >0.495000</td>
#       <td id="T_af9b9_row1_col2" class="data row1 col2" >0.500100</td>
#       <td id="T_af9b9_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_af9b9_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_af9b9_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_af9b9_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_af9b9_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_af9b9_level0_row2" class="row_heading level0 row2" >clock_speed</th>
#       <td id="T_af9b9_row2_col0" class="data row2 col0" >2000.000000</td>
#       <td id="T_af9b9_row2_col1" class="data row2 col1" >1.522250</td>
#       <td id="T_af9b9_row2_col2" class="data row2 col2" >0.816004</td>
#       <td id="T_af9b9_row2_col3" class="data row2 col3" >0.500000</td>
#       <td id="T_af9b9_row2_col4" class="data row2 col4" >0.700000</td>
#       <td id="T_af9b9_row2_col5" class="data row2 col5" >1.500000</td>
#       <td id="T_af9b9_row2_col6" class="data row2 col6" >2.200000</td>
#       <td id="T_af9b9_row2_col7" class="data row2 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_af9b9_level0_row3" class="row_heading level0 row3" >dual_sim</th>
#       <td id="T_af9b9_row3_col0" class="data row3 col0" >2000.000000</td>
#       <td id="T_af9b9_row3_col1" class="data row3 col1" >0.509500</td>
#       <td id="T_af9b9_row3_col2" class="data row3 col2" >0.500035</td>
#       <td id="T_af9b9_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_af9b9_row3_col4" class="data row3 col4" >0.000000</t

# %% [markdown]
# **There Are some odd values in the dataset**
# * > Zero values for px_height
# * > Zero values for sc_w

# %%
df[df['px_height'] == 0]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1481           1834     0          2.1         0   7       1          40
# 1933            897     1          2.0         0   3       1           2
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1481    0.1         99        4  ...          0      1987  3692    13     0
# 1933    0.6        154        8  ...          0       994  1958     7     5
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 1481         16        1             1     0            3
# 1933          7        1             1     0            1
#
# [2 rows x 21 columns]

# %% [markdown]
# **I am writing a code to check if the values for px_height and px_width are logical or NOT ↓↓↓↓**

# %%
import math

def calculate_aspect_ratio(row):
    height = int(row['px_height'])
    width = int(row['px_width'])
    gcd = math.gcd(height , width)
    simple_height = height // gcd
    simple_width = width // gcd
    return simple_height , simple_width

def check_ratio(row , threshold = 0.1):
    aspect_ratio = calculate_aspect_ratio(row)
    
    lower = 1 - threshold
    upper = 1 + threshold
    
    if lower <= aspect_ratio[0] / aspect_ratio[1] <= upper :
        return True
    else :
        return False
    
df['aspect_ratio'] = df.apply(check_ratio , axis = 1)

# %%
plt.figure(figsize=(10,8))
counts = df['aspect_ratio'].value_counts()
plt.pie(counts, labels =  counts.index , autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('Aspect Ratio Distribution')
plt.show()

# %% [markdown]
# **As you can se most values for PX features are not logical but I do not have access to data owner sp I keep them anyway and drop zero values only**

# %%
df = df.drop(columns = 'aspect_ratio')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
df = df.drop([1481,1933] )
df = df.reset_index(drop= True)
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1993            794     1          0.5         1   0       1           2
# 1994           1965     1          2.6         1   0       0          39
# 1995           1911     0          0.9         1   1       1          36
# 1996           1512     0          0.9         0   4       1          46
# 1997            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1993    0.8        106        6  ...       1222      1890   668    13     4
# 1994    0.2        187        4  ...        915      1965  2032    11    10
# 1995    0.7        108        8  ...        868      1632  3057     9     1
# 1996    0.1        145        5  ...        336       670   869    18    10
# 1997    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1993         19        1             1     0            0
# 1994         16        1             1     1            2
# 1995          5        1             1     0            3
# 1996         19        1             1     1            0
# 1997          2        1             1     1            3
#
# [1998 rows x 21 columns]

# %%
df[df['sc_w'] == 0]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 12             1815     0          2.8         0   2       0          33
# 24              503     0          1.2         1   5       1           8
# 33             1310     1          2.2         1   0       1          51
# 42             1253     1          0.5         1   5       1           5
# 50             1547     1          3.0         1   2       1          14
# ...             ...   ...          ...       ...  ..     ...         ...
# 1917            772     0          1.0         1   0       1          23
# 1919            591     1          0.5         1   1       1          16
# 1944            590     1          1.2         1   0       0          32
# 1952            686     1          2.7         1   0       0          36
# 1979           1454     0          2.6         0   8       0           6
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 12      0.6        159        4  ...        607       748  1482    18     0
# 24      0.4        111        3  ...        201      1245  2583    11     0
# 33      0.6        100        4  ...        178      1919  3845     7     0
# 42      0.2        152        2  ...        685       714  1878    15     0
# 50      0.7        198        3  ...       1042      1832  2059     5     0
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1917    0.6         97        7  ...        317      1805  2782     7     0
# 1919    0.9         90        6  ...        892      1603  3746     5     0
# 1944    0.4        141        6  ...        227       509  1817    10     0
# 1952    0.1        194        4  ...         64       745  1503    10     0
# 1979    0.4        199        3  ...        698      1018  1300    10     0
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 12            2        1             0     0            1
# 24           12        1             0     0            1
# 33           12        1             1     0            3
# 42            4        1             1     0            1
# 50           15        1             0     1            2
# ...         ...      ...           ...   ...          ...
# 1917         17        1             0     0            2
# 1919          5        1             1     0            3
# 1944          6        0             1     0            0
# 1952         13        0             0     0            0
# 1979          2        0             0     1            1
#
# [179 rows x 21 columns]

# %% [markdown]
# **SC_W feature has too many zero values so i am going to drop them**

# %%
df = df.drop(df[df['sc_w'] == 0].index)
df = df.reset_index(drop= True)
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1814            794     1          0.5         1   0       1           2
# 1815           1965     1          2.6         1   0       0          39
# 1816           1911     0          0.9         1   1       1          36
# 1817           1512     0          0.9         0   4       1          46
# 1818            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1814    0.8        106        6  ...       1222      1890   668    13     4
# 1815    0.2        187        4  ...        915      1965  2032    11    10
# 1816    0.7        108        8  ...        868      1632  3057     9     1
# 1817    0.1        145        5  ...        336       670   869    18    10
# 1818    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1814         19        1             1     0            0
# 1815         16        1             1     1            2
# 1816          5        1             1     0            3
# 1817         19        1             1     1            0
# 1818          2        1             1     1            3
#
# [1819 rows x 21 columns]

# %% [markdown]
# # Analyzing The Data

# %%
categoricals = []
numericals = []
for col in df.drop(columns = ['price_range','n_cores']).columns:
    if df[col].nunique() < 4:
        categoricals.append(col)
    else:
        numericals.append(col)
        
print('Categoricals : ' , categoricals)
print('Numericals : ' , numericals)
# Out:
# Categoricals :  ['blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']
# Numericals :  ['battery_power', 'clock_speed', 'fc', 'int_memory', 'm_dep', 'mobile_wt', 'pc', 'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time']

# %%
fig,axs = plt.subplots(nrows = 3,ncols = 2,figsize = (40,30))
axs = axs.flatten()
for i,var in enumerate(categoricals) :
    sns.countplot(x = var , data = df,ax = axs[i])
    axs[i].set_xticklabels(axs[i].get_xticklabels(),rotation = 90,fontsize = 20)   
    axs[i].set_xlabel(var ,fontsize=30) 
    axs[i].set_ylabel('Count',fontsize = 20)
    axs[i].tick_params(axis='y', labelsize=25)
    
    for p in axs[i].patches:
                axs[i].annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points',
                fontsize=30)
    



fig.tight_layout()     
plt.show()

# %%
fig,axs = plt.subplots(nrows = 3,ncols = 2,figsize = (40,30))
axs = axs.flatten()
for i,var in enumerate(categoricals) :
    sns.countplot(x = var ,hue = 'price_range', data = df,ax = axs[i])
    axs[i].set_xticklabels(axs[i].get_xticklabels(),rotation = 90,fontsize = 20)   
    axs[i].set_xlabel(var ,fontsize=30) 
    axs[i].set_ylabel('Count',fontsize = 20)
    axs[i].tick_params(axis='y', labelsize=25)
    
    for p in axs[i].patches:
                axs[i].annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points',
                fontsize=30)
    



fig.tight_layout()     
plt.show()

# %%
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(40, 30))
axs = axs.flatten()

variables = ['n_cores']
hues = ['price_range', None]

for i, var in enumerate(variables):
    for j, hue in enumerate(hues):
        index = i * len(hues) + j

        
        ax = sns.countplot(x=var, hue=hue, data=df, ax=axs[index])

        
        for patch in ax.patches:
            x = patch.get_x() + patch.get_width() / 2
            y = patch.get_height()
            ax.text(x, y, int(y), ha='center', fontsize=25)

        axs[index].set_xlabel(var, fontsize=25)
        axs[index].set_ylabel('Count', fontsize=20)
        axs[index].tick_params(axis='x', labelsize=25)
        axs[index].tick_params(axis='y', labelsize=25)

        if hue is not None:
            axs[index].legend(title=hue, fontsize=20)

fig.tight_layout()
plt.show()

# %%
ax = sns.countplot(x='price_range',hue='price_range',data = df)
df['price_range'].value_counts()
# Out:
# 3    461
# 2    456
# 1    451
# 0    451
# Name: price_range, dtype: int64

# %% [markdown]
# **Our Target is perfectly and weirdly balanced!!!**

# %%
fig,axs = plt.subplots(nrows = 7,ncols = 2,figsize = (40,30))
axs = axs.flatten()
for i,var in enumerate(numericals) :
    sns.boxplot(x = var , data = df,ax = axs[i])
    axs[i].set_xlabel(var ,fontsize=25) 
    axs[i].tick_params(axis='x', labelsize=25)
    
        
     

    
fig.tight_layout() 
axs[-1].set_visible(False)  
plt.show()

# %%
fig,axs = plt.subplots(nrows=7,ncols=2,figsize=(20,30))
axs =axs.flatten()
for i,var in enumerate(numericals):
    sns.kdeplot(x=var,hue = 'price_range',data = df,ax=axs[i])
    axs[i].set_xlabel(var ,fontsize=25) 
    axs[i].tick_params(axis='x', labelsize=25)

                      

                      
    
axs[-1].set_visible(False)    
fig.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True,cbar=True,mask=np.tril(np.ones_like(df.corr())) , annot_kws={'size' : 14})
plt.xticks(fontsize=25,rotation=90)
plt.yticks(fontsize=25,rotation=0)

plt.show()

# %% [markdown]
# # Making The Models :

# %%
x = df.drop(columns= 'price_range').values
y = df['price_range'].values.reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,f1_score,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from yellowbrick.classifier import ConfusionMatrix

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2)

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
dt_entropy = DecisionTreeClassifier(criterion = 'entropy')
dt_gini = DecisionTreeClassifier(criterion = 'gini')
rf_entropy = RandomForestClassifier(criterion = 'entropy')
rf_gini = RandomForestClassifier(criterion = 'gini')
svm = SVC()
models = [dt_entropy,dt_gini, rf_entropy,rf_gini , svm]

# %%
for model in models:
    model.fit(x_train,y_train.ravel())
    print(f'Training Score for {model} : {model.score(x_train,y_train)}')
    print(f'Testing Score for {model} : {model.score(x_test,y_test)} \n')
# Out:
# Training Score for DecisionTreeClassifier(criterion='entropy') : 1.0
# Testing Score for DecisionTreeClassifier(criterion='entropy') : 0.8351648351648352
#
# Training Score for DecisionTreeClassifier() : 1.0
# Testing Score for DecisionTreeClassifier() : 0.8571428571428571
#
# Training Score for RandomForestClassifier(criterion='entropy') : 1.0
# Testing Score for RandomForestClassifier(criterion='entropy') : 0.9065934065934066
#
# Training Score for RandomForestClassifier() : 1.0
# Testing Score for RandomForestClassifier() : 0.8846153846153846
#
# Training Score for SVC() : 0.9869415807560138
# Testing Score for SVC() : 0.8571428571428571

# %% [markdown]
# > as we can see, svm was the best here, and DT and RF are overfitting in training so let us continue with svm

# %%
SVM = SVC()
C = [0.1,1,10,100]
kernel = ['linear', 'poly', 'rbf', 'sigmoid']

params = {'C':C,'kernel':kernel}

# %%
grid_search = GridSearchCV(estimator=SVM, param_grid=params, cv=5, scoring='accuracy')
grid_search.fit(x_train,y_train.ravel())
print("Best Parameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)
# Out:
# Best Parameters: {'C': 100, 'kernel': 'linear'}
# Best Accuracy: 0.9546391752577319

# %%
SVM = SVC(C= 10 , kernel = 'linear')
SVM.fit(x_train,y_train.ravel())
print(f'Training Score for {SVM} : {SVM.score(x_train,y_train)}')
print(f'Testing Score for {SVM} : {SVM.score(x_test,y_test)} \n')
# Out:
# Training Score for SVC(C=10, kernel='linear') : 0.9848797250859107
# Testing Score for SVC(C=10, kernel='linear') : 0.9642857142857143

# %%
y_pred = SVM.predict(x_test)
print('Accuracy score :' , accuracy_score(y_test, y_pred))
print('F1 score :' , f1_score(y_test, y_pred , average = 'macro'))
print('\n Classification Report \n' , classification_report(y_test, y_pred))
# Out:
# Accuracy score : 0.9642857142857143
# F1 score : 0.9649303319382925
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        89
#            1       0.96      0.96      0.96       101
#            2       0.94      0.95      0.94        95
#            3       0.97      0.96      0.97        79
#
#     accuracy                           0.96       364
#    macro avg       0.97      0.96      0.96       364
# weighted avg       0.96      0.96      0.96       364

# %%
cm = ConfusionMatrix(SVM ,classes= ['class 0' ,'class 1' ,'class 2' ,'class 3' ] )
cm.fit(x_train , y_train)
cm.score(x_test,y_test)
cm.show()
# Out:
# <AxesSubplot:title={'center':'SVC Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# > the model is all right ,now let's use the test data

# %%
x_test = df_test.values

x_train = scaler.fit_transform(x)
x_test = scaler.transform(x_test)

# %%
SVM.fit(x_train , y.ravel())
SVM.score(x_train , y)
# Out:
# 0.9846069268829027

# %%
df_test['price_range'] = SVM.predict(x_test)
df_test
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0      0.1        193        3  ...        226      1412  3476    12     7
# 1      0.8        191        5  ...        746       857  3895     6     0
# 2      0.9        186        3  ...       1270      1366  2396    17    10
# 3      0.5         96        8  ...        295      1752  3893    10     0
# 4      0.5        108        6  ...        749       810  1773    15     8
# ..     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 995    0.5        170        7  ...        644       913  2121    14     8
# 996    0.9        186        4  ...       1152      1632  1933     8     1
# 997    0.5         80        1  ...        477       825  1223     5     0
# 998    0.4        171        2  ...         38       832  2509    15    11
# 999    0.1        140        6  ...        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi  price_range
# 0            2        0             1     0            3
# 1            7        1             0     0            3
# 2           10        0             1     1            2
# 3            7        1             1     0            3
# 4            7        1             0     1            1
# ..         ...      ...           ...   ...          ...
# 995         15        1             1     0            2
# 996         19        0             1     1            1
# 997         14        1             0     0            0
# 998          6        0             1     0            2
# 999          3        1             0     1            2
#
# [1000 rows x 21 columns]

# %%
merged_df = pd.concat([df, df_test], axis=0, ignore_index=True)
merged_df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 2814           1700     1          1.9         0   0       1          54
# 2815            609     0          1.8         1   0       0          13
# 2816           1185     0          1.4         0   1       1           8
# 2817           1533     1          0.5         1   0       0          50
# 2818           1270     1          0.5         0   4       1          35
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 2814    0.5        170        7  ...        644       913  2121    14     8
# 2815    0.9        186        4  ...       1152      1632  1933     8     1
# 2816    0.5         80        1  ...        477       825  1223     5     0
# 2817    0.4        171        2  ...         38       832  2509    15    11
# 2818    0.1        140        6  ...        457       608  2828     9     2
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 2814         15        1             1     0            2
# 2815         19        0             1     1            1
# 2816         14        1             0     0            0
# 2817          6        0             1     0            2
# 2818          3        1             0     1            2
#
# [2819 rows x 21 columns]
